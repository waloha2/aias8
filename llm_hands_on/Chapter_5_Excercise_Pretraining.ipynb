# %%
# Copyright (c) Sebastian Raschka under Apache License 2.0 (see LICENSE.txt).
# Source for "Build a Large Language Model From Scratch"
#   - https://www.manning.com/books/build-a-large-language-model-from-scratch
# Code: https://github.com/rasbt/LLMs-from-scratch

import matplotlib.pyplot as plt
import os
import requests
import torch
import tiktoken

from previous_chapters import GPTModel, create_dataloader_v1, generate_text_simple

# %%
### 중요: lOSS를 계산합니다.
def calc_loss_batch(input_batch, target_batch, model, device):
    """
    하나의 배치(Batch)에 대해 모델의 예측값과 실제값 사이의 오차(Loss)를 계산합니다.
    """
    # 데이터를 GPU(또는 설정된 device)로 이동
    input_batch, target_batch = input_batch.to(device), target_batch.to(device)
    
    # 1. 모델의 순전파(Forward Pass)
    # logits shape: (batch_size, sequence_length, vocab_size)
    logits = model(input_batch)
    
    # 2. 손실 계산 (CrossEntropyLoss)
    # PyTorch의 CrossEntropyLoss는 입력을 (N, C) 형태로 받기를 원합니다.
    #   - N: 전체 샘플 수 (여기서는 Batch_size * Sequence_length)
    #   - C: 클래스 수 (여기서는 Vocab_size)
    # 따라서 3차원 텐서를 2차원으로 평탄화(flatten) 해야 합니다.
    
    # logits.flatten(0, 1) -> (batch_size * sequence_length, vocab_size)
    # target_batch.flatten() -> (batch_size * sequence_length)
    # region [손실 계산 (CrossEntropyLoss)]
    # TODO: 손실 함수명과 logits/target 평탄화 메서드를 채우세요.
    # 힌트: cross_entropy에 logits.flatten(0, 1)과 target_batch.flatten()을 전달합니다.
    loss = torch.nn.functional.cross_entropy(
        logits.flatten(0, 1), 
        target_batch.flatten()
    )
    # endregion
    return loss

# %%
### 중요: 모델을 학습합니다.
def train_model_simple(model, train_loader, val_loader, optimizer, device, num_epochs,
                       eval_freq, eval_iter, start_context, tokenizer):
    """
    [핵심] 모델 훈련을 담당하는 메인 루프입니다.
    """
    # 로그 저장을 위한 리스트들
    train_losses, val_losses, track_tokens_seen = [], [], []
    tokens_seen = 0
    global_step = -1

    # Epoch: 전체 데이터셋을 한 번 훑는 단위
    for epoch in range(num_epochs):
        # region [train 모드 설정]
        # TODO: 모델 모드 전환 메서드를 채우세요.
        # 힌트: 학습 루프 시작 전에는 train 모드를 설정해야 합니다.
        model.train()  # 훈련 시작 전 반드시 train 모드 설정
        # endregion
        
        for input_batch, target_batch in train_loader:
            # [Step 1] 이전 배치에서 계산된 기울기 초기화 (필수)
            # region [기울기 초기화]
            # TODO: 기울기 초기화 메서드를 채우세요.
            # 힌트: 배치마다 이전 gradient가 누적되지 않도록 zero_grad()를 먼저 호출합니다.
            optimizer.zero_grad()
            # endregion
            #              
            # [Step 2] 순전파 및 손실 계산
            # region [손실 계산]
            # TODO: 배치 손실 계산 함수명을 채우세요.
            # 힌트: input_batch, target_batch, model, device를 인자로 받는 헬퍼를 호출하면 됩니다.
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            # endregion

            # [Step 3] 역전파 (Backpropagation): 각 파라미터별 기울기(Gradient) 계산
            # region [역전파 수행]
            # TODO: 역전파 메서드를 채우세요.
            # 힌트: loss 텐서에서 backward()를 호출해 gradient를 계산합니다.
            loss.backward() 
            # endregion

            # [Step 4] 가중치 업데이트: 계산된 기울기를 이용해 파라미터 수정
            # region [가중치 업데이트]
            # TODO: 파라미터 업데이트 메서드를 채우세요.
            # 힌트: backward()로 계산된 gradient를 이용해 optimizer.step()으로 가중치를 갱신합니다.
            optimizer.step() 
            # endregion
            
            tokens_seen += input_batch.numel() # 처리한 토큰 수 카운트
            global_step += 1

            # 일정 스텝마다 검증(Evaluation) 수행 및 로그 출력
            if global_step % eval_freq == 0:
                train_loss, val_loss = evaluate_model(
                    model, train_loader, val_loader, device, eval_iter)
                train_losses.append(train_loss)
                val_losses.append(val_loss)
                track_tokens_seen.append(tokens_seen)
                print(f"Ep {epoch+1} (Step {global_step:06d}): "
                      f"Train loss {train_loss:.3f}, Val loss {val_loss:.3f}")

        # 한 에포크가 끝날 때마다 샘플 문장을 생성하여 모델이 똑똑해지고 있는지 확인
        generate_and_print_sample(
            model, tokenizer, device, start_context
        )

    return train_losses, val_losses, track_tokens_seen

# %%
### 중요: 결과를 생성합니다.
def generate(model, idx, max_new_tokens, context_size, eos_id=None):
    """
    고급 텍스트 생성 함수입니다. (Top-k 샘플링 & Temperature Scaling 포함)
    
    Args:
        idx: 현재 문맥 (Shape: Batch, Time)
        temperature: 0이면 결정적(Greedy), 높을수록 창의적/랜덤
        top_k: 확률 상위 k개만 후보로 남김 (이상한 단어 생성 방지)
    """

    # 지정된 토큰 수만큼 반복 생성
    for _ in range(max_new_tokens):
        
        # 1. 문맥 자르기 (Context Cropping)
        # 모델이 처리할 수 있는 최대 길이(context_size)를 넘지 않도록 뒤쪽만 남김
        idx_cond = idx[:, -context_size:]
        
        # 2. 모델 예측
        # region [모델 예측]
        with torch.no_grad():
            logits = model(idx_cond)
        # endregion

        # 3. 다음 단어 예측을 위해 '마지막 시점'의 로짓만 추출
        # logits shape: (batch, seq_len, vocab_size) -> (batch, vocab_size)
        # region [마지막 시점 로짓 추출]
        # TODO: 마지막 시점 선택 인덱스를 채우세요.
        # 힌트: 다음 토큰 생성은 마지막 위치 logits만 사용합니다.
        logits = logits[:, -1, :]
        # endregion

        # 가장 높은 확률을 가진 토큰 선택 (Greedy Decoding)
        # region [다음 토큰 선택 (Greedy Decoding)]
        # TODO: 다음 토큰 선택 함수명을 채우세요.
        # 힌트: Greedy decoding에서는 argmax를 사용합니다.
        idx_next = torch.argmax(logits, dim=-1, keepdim=True)
        # endregion

        # 4. 종료 조건 확인 (EOS 토큰이 나오면 중단)
        if idx_next == eos_id:
            break

        # 5. 생성된 토큰 이어붙이기
        # 기존 문장(idx) 뒤에 새로 뽑은 토큰(idx_next)을 붙여 다음 스텝의 입력으로 씀
        # region [생성된 토큰 이어붙이기]
        # TODO: concat 대상 변수를 채우세요.
        # 힌트: 방금 고른 idx_next를 기존 idx 뒤에 붙입니다.
        idx = torch.cat((idx, idx_next), dim=1)
        # endregion
        
    return idx

# %%
def text_to_token_ids(text, tokenizer):
    """
    사람이 읽는 텍스트 문자열을 모델이 이해하는 토큰 ID 텐서로 변환합니다.
    """
    encoded = tokenizer.encode(text)
    
    # 모델은 입력으로 (Batch_Size, Sequence_Length)의 2차원 텐서를 요구합니다.
    # 하지만 여기서는 문장 1개이므로 Batch_Size가 없습니다.
    # 따라서 .unsqueeze(0)를 사용하여 가짜 배치 차원을 추가합니다.
    # 예: [12, 34, 56] -> [[12, 34, 56]] (Shape: [1, seq_len])
    # TODO: 배치 차원 추가 메서드를 채우세요.
    # 힌트: 단일 시퀀스를 모델 입력 형태로 만들기 위해 unsqueeze(0)를 사용합니다.
    encoded_tensor = torch.tensor(encoded).unsqueeze(0) 
    return encoded_tensor


def token_ids_to_text(token_ids, tokenizer):
    """
    모델이 뱉어낸 토큰 ID 텐서를 사람이 읽을 수 있는 텍스트로 변환합니다.
    """
    # 디코딩을 위해 불필요한 배치 차원을 제거합니다.
    # 예: [[12, 34, 56]] -> [12, 34, 56]
    # TODO: 배치 차원 제거 메서드를 채우세요.
    # 힌트: 디코딩 전에는 squeeze(0)로 앞쪽 차원을 제거합니다.
    flat = token_ids.squeeze(0) 
    return tokenizer.decode(flat.tolist())


def calc_loss_loader(data_loader, model, device, num_batches=None):
    """
    데이터 로더 전체(또는 일부)를 돌면서 평균 손실을 계산합니다.
    훈련에는 관여하지 않고, 오직 '평가(Evaluation)' 목적으로만 쓰입니다.
    """
    total_loss = 0.
    if len(data_loader) == 0:
        return float("nan")
    elif num_batches is None:
        num_batches = len(data_loader)
    else:
        # 평가 시간을 단축하기 위해 전체 데이터를 다 보지 않고 일부만 볼 수 있게 설정
        num_batches = min(num_batches, len(data_loader))
        
    for i, (input_batch, target_batch) in enumerate(data_loader):
        if i < num_batches:
            loss = calc_loss_batch(input_batch, target_batch, model, device)
            total_loss += loss.item() # 텐서에서 실수값(float)만 추출하여 누적
        else:
            break
    return total_loss / num_batches


def evaluate_model(model, train_loader, val_loader, device, eval_iter):
    """
    현재 모델의 성능을 훈련 세트와 검증 세트 각각에 대해 평가합니다.
    """
    model.eval() # [중요] 평가 모드 전환: Dropout이나 BatchNorm 등의 동작이 변경됨
    
    with torch.no_grad(): # [중요] 기울기(Gradient) 계산 끔 -> 메모리 절약 및 속도 향상
        train_loss = calc_loss_loader(train_loader, model, device, num_batches=eval_iter)
        val_loss = calc_loss_loader(val_loader, model, device, num_batches=eval_iter)
        
    model.train() # 평가가 끝나면 다시 훈련 모드로 복귀해야 함
    return train_loss, val_loss


def generate_and_print_sample(model, tokenizer, device, start_context):
    """
    훈련 중간중간 모델이 문장을 어떻게 생성하는지 눈으로 확인하기 위한 함수입니다.
    """
    model.eval() # 평가 모드
    context_size = model.pos_emb.weight.shape[0] # 모델이 처리 가능한 최대 길이
    encoded = text_to_token_ids(start_context, tokenizer).to(device)
    
    with torch.no_grad():
        token_ids = generate_text_simple(
            model=model, idx=encoded,
            max_new_tokens=50, context_size=context_size
        )
        decoded_text = token_ids_to_text(token_ids, tokenizer)
        
        # 출력이 너무 길어지면 보기 힘드므로 줄바꿈을 공백으로 변경
        print(decoded_text.replace("\n", " "))  
    
    model.train() # 훈련 모드 복귀



def plot_losses(epochs_seen, tokens_seen, train_losses, val_losses):
    """
    훈련 진행 상황(Loss 변화)을 시각화하는 함수입니다.
    X축을 'Epoch'와 '처리한 토큰 수' 두 가지 기준으로 보여줍니다.
    """
    fig, ax1 = plt.subplots()

    # 기본 X축: Epoch 기준
    ax1.plot(epochs_seen, train_losses, label="Training loss")
    ax1.plot(epochs_seen, val_losses, linestyle="-.", label="Validation loss")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")
    ax1.legend(loc="upper right")

    # 보조 X축 (상단): 처리한 토큰 수(Tokens seen) 기준
    ax2 = ax1.twiny() 
    ax2.plot(tokens_seen, train_losses, alpha=0) # 투명한 그래프로 축만 생성
    ax2.set_xlabel("Tokens seen")

    fig.tight_layout() 
    # plt.show() # 주피터 노트북 환경이면 주석 해제


def main(gpt_config, settings):
    # 랜덤 시드 고정 (실험 재현성을 위해)
    torch.manual_seed(123)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    ##############################
    # 1. 데이터 준비
    ##############################
    '''
    file_path = "datas/the-verdict.txt"
    url = "https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/main/ch02/01_main-chapter-code/the-verdict.txt"

    if not os.path.exists(file_path):
        response = requests.get(url, timeout=30)
        response.raise_for_status()
        text_data = response.text
        with open(file_path, "w", encoding="utf-8") as file:
            file.write(text_data)
    else:
        with open(file_path, "r", encoding="utf-8") as file:
            text_data = file.read()
    '''
    data_dir = "datas/"
    datasets = {
        "the-verdict": {
            "file": os.path.join(data_dir, "the-verdict.txt"),
            "url": "https://raw.githubusercontent.com/rasbt/LLMs-from-scratch/main/ch02/01_main-chapter-code/the-verdict.txt"
        },
        "tiny-shakespeare": {
            "file": os.path.join(data_dir, "tiny-shakespeare.txt"),
            "url": "https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt"
        }
    }
    
    text_data = ""
    
    # 루프를 돌며 데이터 로드 및 합치기
    for name, info in datasets.items():
        file_path = info["file"]
        url = info["url"]
    
        if not os.path.exists(file_path):
            response = requests.get(url, timeout=30)
            response.raise_for_status()
            content = response.text
            with open(file_path, "w", encoding="utf-8") as file:
                file.write(content)
        else:
            with open(file_path, "r", encoding="utf-8") as file:
                content = file.read()
        
        # 텍스트 데이터 이어 붙이기 (구분을 위해 줄바꿈 추가)
        text_data += content + "\n\n"
    
    print(f"전체 텍스트 길이: {len(text_data)} 글자")

    
    ##############################
    # 2. 모델 및 옵티마이저 초기화
    ##############################
    model = GPTModel(gpt_config)
    model.to(device) # 모델을 GPU 메모리로 올림
    
    # AdamW: 가중치 감쇠(Weight Decay)가 적용된 Adam 옵티마이저
    # Weight Decay는 모델이 너무 복잡해지지 않도록 규제(Regularization)하는 역할
    # TODO: AdamW에 넘길 파라미터 이터레이터와 학습률 키워드를 채우세요.
    # 힌트: 첫 번째 인자는 model.parameters(), 학습률은 lr=settings["learning_rate"] 형태입니다.
    optimizer = torch.optim.AdamW(
        model.parameters(), lr=settings["learning_rate"], weight_decay=settings["weight_decay"]
    )

    ##############################
    # 3. 데이터 로더 구축
    ##############################
    # 전체 텍스트를 9:1 비율로 훈련용과 검증용으로 나눔
    train_ratio = 0.90
    split_idx = int(train_ratio * len(text_data))

    # 훈련 데이터 로더: 순서를 섞음(Shuffle=True)
    train_loader = create_dataloader_v1(
        text_data[:split_idx],
        batch_size=settings["batch_size"],
        max_length=gpt_config["context_length"],
        stride=gpt_config["context_length"],
        drop_last=True,
        shuffle=True,
        num_workers=0
    )

    # 검증 데이터 로더: 순서를 섞지 않음(Shuffle=False) -> 평가는 일관되게
    val_loader = create_dataloader_v1(
        text_data[split_idx:],
        batch_size=settings["batch_size"],
        max_length=gpt_config["context_length"],
        stride=gpt_config["context_length"],
        drop_last=False,
        shuffle=False,
        num_workers=0
    )

    ##############################
    # 4. 훈련 시작
    ##############################
    tokenizer = tiktoken.get_encoding("gpt2") # BPE 토크나이저

    train_losses, val_losses, tokens_seen = train_model_simple(
        model, train_loader, val_loader, optimizer, device,
        num_epochs=settings["num_epochs"], eval_freq=5, eval_iter=1,
        start_context="Every effort moves you", tokenizer=tokenizer
    )

    return train_losses, val_losses, tokens_seen, model

# %%
# GPT-2 Small (124M) 모델 설정
GPT_CONFIG_124M = {
    "vocab_size": 50257,    # 어휘 크기
    "context_length": 256,  # 훈련 속도를 위해 원본(1024)보다 줄임
    "emb_dim": 768,         # 임베딩 벡터 차원
    "n_heads": 12,          # 어텐션 헤드 개수
    "n_layers": 12,         # 레이어 깊이
    "drop_rate": 0.3,       # 과적합 방지 드롭아웃
    "qkv_bias": False       
}

# 학습 하이퍼파라미터
OTHER_SETTINGS = {
    "learning_rate": 1e-4, 
    "num_epochs": 10,       
    "batch_size": 8,        
    "weight_decay": 0.1     
}

###########################
# 메인 실행: 훈련
###########################
train_losses, val_losses, tokens_seen, model = main(GPT_CONFIG_124M, OTHER_SETTINGS)

###########################
# 훈련 결과 시각화 및 저장
###########################

# 에포크 축 생성 (0부터 num_epochs까지)
epochs_tensor = torch.linspace(0, OTHER_SETTINGS["num_epochs"], len(train_losses))
plot_losses(epochs_tensor, tokens_seen, train_losses, val_losses)
plt.savefig("outputs/loss.pdf")

# 모델 저장 및 로드 테스트
torch.save(model.state_dict(), "outputs/model.pth")

# 디바이스 설정 (모델 로드 전에 정의 필요)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 모델 다시 불러오기 테스트
model = GPTModel(GPT_CONFIG_124M) # 1. 빈 모델 생성 (현재 CPU에 있음)
model.load_state_dict(torch.load("outputs/model.pth", weights_only=True)) # 2. 가중치 로드
model.to(device) # <--- [핵심 수정] 3. 모델을 GPU로 이동시켜야 함

torch.manual_seed(123)
###########################
# 생성 테스트 (Inference)
###########################
tokenizer = tiktoken.get_encoding("gpt2")

# 훈련된 모델로 텍스트 생성 시도
# Temperature=1.4로 설정하여 다소 창의적/다양한 문장 생성 유도
token_ids = generate(
    model=model,
    idx=text_to_token_ids("Every effort moves you", tokenizer).to(device),
    max_new_tokens=15,
    context_size=GPT_CONFIG_124M["context_length"]
)

print("출력 텍스트:\n", token_ids_to_text(token_ids, tokenizer))
# Out:
# 전체 텍스트 길이: 1135877 글자
# Ep 1 (Step 000000): Train loss 10.210, Val loss 10.135
# Ep 1 (Step 000005): Train loss 8.830, Val loss 8.687
# Ep 1 (Step 000010): Train loss 8.397, Val loss 8.263
# Ep 1 (Step 000015): Train loss 7.995, Val loss 7.861
# Ep 1 (Step 000020): Train loss 7.591, Val loss 7.493
# Ep 1 (Step 000025): Train loss 7.208, Val loss 7.162
# Ep 1 (Step 000030): Train loss 6.827, Val loss 6.883
# Ep 1 (Step 000035): Train loss 6.827, Val loss 6.673
# Ep 1 (Step 000040): Train loss 6.560, Val loss 6.513
# Ep 1 (Step 000045): Train loss 6.475, Val loss 6.402
# Ep 1 (Step 000050): Train loss 6.460, Val loss 6.321
# Ep 1 (Step 000055): Train loss 6.261, Val loss 6.259
# Ep 1 (Step 000060): Train loss 6.338, Val loss 6.223
# Ep 1 (Step 000065): Train loss 6.170, Val loss 6.198
# Ep 1 (Step 000070): Train loss 6.066, Val loss 6.185
# Ep 1 (Step 000075): Train loss 6.091, Val loss 6.166
# Ep 1 (Step 000080): Train loss 6.078, Val loss 6.140
# Ep 1 (Step 000085): Train loss 6.391, Val loss 6.126
# Ep 1 (Step 000090): Train loss 5.858, Val loss 6.101
# Ep 1 (Step 000095): Train loss 6.182, Val loss 6.085
# Ep 1 (Step 000100): Train loss 5.801, Val loss 6.057
# Ep 1 (Step 000105): Train loss 6.109, Val loss 6.050
# Ep 1 (Step 000110): Train loss 5.845, Val loss 6.016
# Ep 1 (Step 000115): Train loss 5.579, Val loss 5.992
# Ep 1 (Step 000120): Train loss 5.754, Val loss 5.957
# Ep 1 (Step 000125): Train loss 5.503, Val loss 5.936
# Ep 1 (Step 000130): Train loss 5.779, Val loss 5.909
# Ep 1 (Step 000135): Train loss 5.719, Val loss 5.897
# Ep 1 (Step 000140): Train loss 5.758, Val loss 5.873
# Ep 1 (Step 000145): Train loss 5.299, Val loss 5.880
# Every effort moves you,          IUS:              IUS:              IUS:
# Ep 2 (Step 000150): Train loss 5.664, Val loss 5.884
# Ep 2 (Step 000155): Train loss 5.445, Val loss 5.836
# Ep 2 (Step 000160): Train loss 5.449, Val loss 5.822
# Ep 2 (Step 000165): Train loss 5.651, Val loss 5.795
# Ep 2 (Step 000170): Train loss 5.520, Val loss 5.798
# Ep 2 (Step 000175): Train loss 5.465, Val loss 5.771
# Ep 2 (Step 000180): Train loss 5.714, Val loss 5.785
# Ep 2 (Step 000185): Train loss 5.301, Val loss 5.770
# Ep 2 (Step 000190): Train loss 5.482, Val loss 5.739
# Ep 2 (Step 000195): Train loss 5.261, Val loss 5.738
# Ep 2 (Step 000200): Train loss 5.264, Val loss 5.722
# Ep 2 (Step 000205): Train loss 5.664, Val loss 5.717
# Ep 2 (Step 000210): Train loss 5.236, Val loss 5.715
# Ep 2 (Step 000215): Train loss 5.237, Val loss 5.713
# Ep 2 (Step 000220): Train loss 4.854, Val loss 5.692
# Ep 2 (Step 000225): Train loss 5.218, Val loss 5.668
# Ep 2 (Step 000230): Train loss 5.256, Val loss 5.644
# Ep 2 (Step 000235): Train loss 5.172, Val loss 5.619
# Ep 2 (Step 000240): Train loss 5.226, Val loss 5.616
# Ep 2 (Step 000245): Train loss 5.076, Val loss 5.565
# Ep 2 (Step 000250): Train loss 5.014, Val loss 5.562
# Ep 2 (Step 000255): Train loss 5.650, Val loss 5.530
# Ep 2 (Step 000260): Train loss 4.853, Val loss 5.510
# Ep 2 (Step 000265): Train loss 5.247, Val loss 5.502
# Ep 2 (Step 000270): Train loss 5.133, Val loss 5.496
# Ep 2 (Step 000275): Train loss 5.182, Val loss 5.512
# Ep 2 (Step 000280): Train loss 4.816, Val loss 5.479
# Ep 2 (Step 000285): Train loss 5.153, Val loss 5.476
# Ep 2 (Step 000290): Train loss 5.169, Val loss 5.459
# Ep 2 (Step 000295): Train loss 4.980, Val loss 5.481
# Every effort moves you, And I have been, And I have a man, And I have a man, And I'll not, And I'll not, And I have a man, And I am a man, And I
# Ep 3 (Step 000300): Train loss 5.282, Val loss 5.461
# Ep 3 (Step 000305): Train loss 5.161, Val loss 5.447
# Ep 3 (Step 000310): Train loss 4.600, Val loss 5.414
# Ep 3 (Step 000315): Train loss 5.108, Val loss 5.435
# Ep 3 (Step 000320): Train loss 5.089, Val loss 5.434
# Ep 3 (Step 000325): Train loss 5.196, Val loss 5.435
# Ep 3 (Step 000330): Train loss 5.099, Val loss 5.450
# Ep 3 (Step 000335): Train loss 4.629, Val loss 5.422
# Ep 3 (Step 000340): Train loss 4.635, Val loss 5.426
# Ep 3 (Step 000345): Train loss 4.618, Val loss 5.390
# Ep 3 (Step 000350): Train loss 5.037, Val loss 5.358
# Ep 3 (Step 000355): Train loss 5.086, Val loss 5.357
# Ep 3 (Step 000360): Train loss 4.984, Val loss 5.386
# Ep 3 (Step 000365): Train loss 5.015, Val loss 5.363
# Ep 3 (Step 000370): Train loss 4.680, Val loss 5.360
# Ep 3 (Step 000375): Train loss 5.096, Val loss 5.353
# Ep 3 (Step 000380): Train loss 5.024, Val loss 5.339
# Ep 3 (Step 000385): Train loss 4.992, Val loss 5.329
# Ep 3 (Step 000390): Train loss 4.615, Val loss 5.325
# Ep 3 (Step 000395): Train loss 4.897, Val loss 5.309
# Ep 3 (Step 000400): Train loss 5.105, Val loss 5.320
# Ep 3 (Step 000405): Train loss 5.070, Val loss 5.340
# Ep 3 (Step 000410): Train loss 4.829, Val loss 5.292
# Ep 3 (Step 000415): Train loss 4.931, Val loss 5.284
# Ep 3 (Step 000420): Train loss 4.675, Val loss 5.283
# Ep 3 (Step 000425): Train loss 4.814, Val loss 5.290
# Ep 3 (Step 000430): Train loss 4.952, Val loss 5.268
# Ep 3 (Step 000435): Train loss 5.061, Val loss 5.315
# Ep 3 (Step 000440): Train loss 4.433, Val loss 5.249
# Ep 3 (Step 000445): Train loss 4.790, Val loss 5.247
# Every effort moves you, And I have you, And I have you, And you have you, And you have you have you, And you have you have you, And you, And you have you, And you,
# Ep 4 (Step 000450): Train loss 4.493, Val loss 5.196
# Ep 4 (Step 000455): Train loss 4.636, Val loss 5.214
# Ep 4 (Step 000460): Train loss 4.677, Val loss 5.205
# Ep 4 (Step 000465): Train loss 4.612, Val loss 5.200
# Ep 4 (Step 000470): Train loss 4.404, Val loss 5.198
# Ep 4 (Step 000475): Train loss 4.777, Val loss 5.192
# Ep 4 (Step 000480): Train loss 4.749, Val loss 5.218
# Ep 4 (Step 000485): Train loss 4.752, Val loss 5.229
# Ep 4 (Step 000490): Train loss 4.620, Val loss 5.213
# Ep 4 (Step 000495): Train loss 4.616, Val loss 5.182
# Ep 4 (Step 000500): Train loss 4.621, Val loss 5.201
# Ep 4 (Step 000505): Train loss 4.567, Val loss 5.186
# Ep 4 (Step 000510): Train loss 4.772, Val loss 5.193
# Ep 4 (Step 000515): Train loss 4.621, Val loss 5.207
# Ep 4 (Step 000520): Train loss 4.658, Val loss 5.154
# Ep 4 (Step 000525): Train loss 4.736, Val loss 5.144
# Ep 4 (Step 000530): Train loss 4.823, Val loss 5.131
# Ep 4 (Step 000535): Train loss 4.569, Val loss 5.129
# Ep 4 (Step 000540): Train loss 4.515, Val loss 5.111
# Ep 4 (Step 000545): Train loss 4.630, Val loss 5.135
# Ep 4 (Step 000550): Train loss 4.569, Val loss 5.105
# Ep 4 (Step 000555): Train loss 4.635, Val loss 5.111
# Ep 4 (Step 000560): Train loss 4.583, Val loss 5.109
# Ep 4 (Step 000565): Train loss 4.594, Val loss 5.096
# Ep 4 (Step 000570): Train loss 4.544, Val loss 5.068
# Ep 4 (Step 000575): Train loss 4.470, Val loss 5.076
# Ep 4 (Step 000580): Train loss 4.411, Val loss 5.085
# Ep 4 (Step 000585): Train loss 4.583, Val loss 5.067
# Ep 4 (Step 000590): Train loss 4.544, Val loss 5.078
# Ep 4 (Step 000595): Train loss 4.449, Val loss 5.082
# Every effort moves you, And I have you have you have you have you have you.             IUS:       IUS:     IUS:
# Ep 5 (Step 000600): Train loss 4.691, Val loss 5.032
# Ep 5 (Step 000605): Train loss 4.578, Val loss 5.043
# Ep 5 (Step 000610): Train loss 4.666, Val loss 4.999
# Ep 5 (Step 000615): Train loss 4.490, Val loss 5.018
# Ep 5 (Step 000620): Train loss 4.337, Val loss 5.022
# Ep 5 (Step 000625): Train loss 4.545, Val loss 4.976
# Ep 5 (Step 000630): Train loss 4.747, Val loss 4.990
# Ep 5 (Step 000635): Train loss 4.780, Val loss 4.988
# Ep 5 (Step 000640): Train loss 4.365, Val loss 4.988
# Ep 5 (Step 000645): Train loss 4.729, Val loss 5.001
# Ep 5 (Step 000650): Train loss 4.472, Val loss 5.013
# Ep 5 (Step 000655): Train loss 4.200, Val loss 4.965
# Ep 5 (Step 000660): Train loss 4.717, Val loss 4.952
# Ep 5 (Step 000665): Train loss 4.521, Val loss 4.972
# Ep 5 (Step 000670): Train loss 4.396, Val loss 4.974
# Ep 5 (Step 000675): Train loss 4.626, Val loss 4.933
# Ep 5 (Step 000680): Train loss 4.414, Val loss 4.934
# Ep 5 (Step 000685): Train loss 4.434, Val loss 4.929
# Ep 5 (Step 000690): Train loss 4.368, Val loss 4.948
# Ep 5 (Step 000695): Train loss 4.098, Val loss 4.938
# Ep 5 (Step 000700): Train loss 4.515, Val loss 4.973
# Ep 5 (Step 000705): Train loss 4.369, Val loss 4.961
# Ep 5 (Step 000710): Train loss 4.413, Val loss 4.955
# Ep 5 (Step 000715): Train loss 4.596, Val loss 4.972
# Ep 5 (Step 000720): Train loss 4.323, Val loss 4.951
# Ep 5 (Step 000725): Train loss 4.571, Val loss 4.960
# Ep 5 (Step 000730): Train loss 4.412, Val loss 4.938
# Ep 5 (Step 000735): Train loss 4.679, Val loss 4.962
# Ep 5 (Step 000740): Train loss 4.363, Val loss 4.966
# Every effort moves you, And you have you have you have you have you have you.       IUS:  IUS: IUS:  IUS: IUS: IUS: IUS
# Ep 6 (Step 000745): Train loss 4.645, Val loss 4.982
# Ep 6 (Step 000750): Train loss 4.622, Val loss 4.958
# Ep 6 (Step 000755): Train loss 4.766, Val loss 5.024
# Ep 6 (Step 000760): Train loss 4.582, Val loss 4.968
# Ep 6 (Step 000765): Train loss 4.372, Val loss 4.977
# Ep 6 (Step 000770): Train loss 4.462, Val loss 4.958
# Ep 6 (Step 000775): Train loss 4.600, Val loss 4.941
# Ep 6 (Step 000780): Train loss 4.706, Val loss 4.955
# Ep 6 (Step 000785): Train loss 4.040, Val loss 4.954
# Ep 6 (Step 000790): Train loss 4.443, Val loss 4.937
# Ep 6 (Step 000795): Train loss 4.334, Val loss 4.945
# Ep 6 (Step 000800): Train loss 4.234, Val loss 4.946
# Ep 6 (Step 000805): Train loss 4.534, Val loss 4.925
# Ep 6 (Step 000810): Train loss 4.250, Val loss 4.926
# Ep 6 (Step 000815): Train loss 4.240, Val loss 4.890
# Ep 6 (Step 000820): Train loss 4.204, Val loss 4.904
# Ep 6 (Step 000825): Train loss 4.517, Val loss 4.880
# Ep 6 (Step 000830): Train loss 4.327, Val loss 4.891
# Ep 6 (Step 000835): Train loss 4.239, Val loss 4.875
# Ep 6 (Step 000840): Train loss 4.446, Val loss 4.876
# Ep 6 (Step 000845): Train loss 4.302, Val loss 4.887
# Ep 6 (Step 000850): Train loss 4.225, Val loss 4.854
# Ep 6 (Step 000855): Train loss 4.448, Val loss 4.888
# Ep 6 (Step 000860): Train loss 4.297, Val loss 4.836
# Ep 6 (Step 000865): Train loss 4.270, Val loss 4.842
# Ep 6 (Step 000870): Train loss 4.050, Val loss 4.854
# Ep 6 (Step 000875): Train loss 4.402, Val loss 4.835
# Ep 6 (Step 000880): Train loss 3.958, Val loss 4.847
# Ep 6 (Step 000885): Train loss 4.212, Val loss 4.847
# Ep 6 (Step 000890): Train loss 4.288, Val loss 4.874
# Every effort moves you, And, to the king, And, And, my lord, And, And, And, my lord, And, my lord, And, And, And, my lord, And,
# Ep 7 (Step 000895): Train loss 4.201, Val loss 4.851
# Ep 7 (Step 000900): Train loss 4.308, Val loss 4.852
# Ep 7 (Step 000905): Train loss 4.230, Val loss 4.860
# Ep 7 (Step 000910): Train loss 4.271, Val loss 4.899
# Ep 7 (Step 000915): Train loss 4.139, Val loss 4.872
# Ep 7 (Step 000920): Train loss 3.971, Val loss 4.855
# Ep 7 (Step 000925): Train loss 4.345, Val loss 4.861
# Ep 7 (Step 000930): Train loss 4.043, Val loss 4.856
# Ep 7 (Step 000935): Train loss 4.197, Val loss 4.873
# Ep 7 (Step 000940): Train loss 3.954, Val loss 4.843
# Ep 7 (Step 000945): Train loss 4.104, Val loss 4.837
# Ep 7 (Step 000950): Train loss 3.923, Val loss 4.839
# Ep 7 (Step 000955): Train loss 4.062, Val loss 4.832
# Ep 7 (Step 000960): Train loss 4.218, Val loss 4.823
# Ep 7 (Step 000965): Train loss 4.200, Val loss 4.818
# Ep 7 (Step 000970): Train loss 4.275, Val loss 4.842
# Ep 7 (Step 000975): Train loss 4.043, Val loss 4.811
# Ep 7 (Step 000980): Train loss 4.329, Val loss 4.789
# Ep 7 (Step 000985): Train loss 4.232, Val loss 4.803
# Ep 7 (Step 000990): Train loss 4.226, Val loss 4.823
# Ep 7 (Step 000995): Train loss 3.900, Val loss 4.797
# Ep 7 (Step 001000): Train loss 4.128, Val loss 4.814
# Ep 7 (Step 001005): Train loss 4.159, Val loss 4.794
# Ep 7 (Step 001010): Train loss 3.667, Val loss 4.776
# Ep 7 (Step 001015): Train loss 4.215, Val loss 4.762
# Ep 7 (Step 001020): Train loss 4.501, Val loss 4.800
# Ep 7 (Step 001025): Train loss 4.083, Val loss 4.789
# Ep 7 (Step 001030): Train loss 3.921, Val loss 4.796
# Ep 7 (Step 001035): Train loss 3.900, Val loss 4.760
# Ep 7 (Step 001040): Train loss 4.142, Val loss 4.796
# Every effort moves you.  DUKE VINCENTIO: I'll not so, sir, sir, sir, I'll not so, sir, sir, sir, sir, I am a And I am a And I have
# Ep 8 (Step 001045): Train loss 4.302, Val loss 4.756
# Ep 8 (Step 001050): Train loss 4.088, Val loss 4.768
# Ep 8 (Step 001055): Train loss 4.137, Val loss 4.776
# Ep 8 (Step 001060): Train loss 3.975, Val loss 4.792
# Ep 8 (Step 001065): Train loss 3.916, Val loss 4.800
# Ep 8 (Step 001070): Train loss 3.864, Val loss 4.760
# Ep 8 (Step 001075): Train loss 4.099, Val loss 4.799
# Ep 8 (Step 001080): Train loss 3.929, Val loss 4.770
# Ep 8 (Step 001085): Train loss 4.022, Val loss 4.783
# Ep 8 (Step 001090): Train loss 4.015, Val loss 4.773
# Ep 8 (Step 001095): Train loss 4.135, Val loss 4.760
# Ep 8 (Step 001100): Train loss 3.980, Val loss 4.780
# Ep 8 (Step 001105): Train loss 3.982, Val loss 4.780
# Ep 8 (Step 001110): Train loss 4.216, Val loss 4.764
# Ep 8 (Step 001115): Train loss 4.004, Val loss 4.757
# Ep 8 (Step 001120): Train loss 4.133, Val loss 4.782
# Ep 8 (Step 001125): Train loss 3.973, Val loss 4.779
# Ep 8 (Step 001130): Train loss 4.220, Val loss 4.787
# Ep 8 (Step 001135): Train loss 4.160, Val loss 4.769
# Ep 8 (Step 001140): Train loss 4.086, Val loss 4.780
# Ep 8 (Step 001145): Train loss 4.088, Val loss 4.752
# Ep 8 (Step 001150): Train loss 3.929, Val loss 4.720
# Ep 8 (Step 001155): Train loss 3.886, Val loss 4.764
# Ep 8 (Step 001160): Train loss 4.052, Val loss 4.737
# Ep 8 (Step 001165): Train loss 3.965, Val loss 4.731
# Ep 8 (Step 001170): Train loss 4.090, Val loss 4.761
# Ep 8 (Step 001175): Train loss 4.112, Val loss 4.741
# Ep 8 (Step 001180): Train loss 4.297, Val loss 4.740
# Ep 8 (Step 001185): Train loss 3.894, Val loss 4.697
# Ep 8 (Step 001190): Train loss 3.920, Val loss 4.696
# Every effort moves you, And I have you have you to your honour.  MENENIUS:  CORIUS: IUS: IOLANUS: IUS: IOLANUS: IUS:
# Ep 9 (Step 001195): Train loss 3.949, Val loss 4.722
# Ep 9 (Step 001200): Train loss 3.739, Val loss 4.704
# Ep 9 (Step 001205): Train loss 3.824, Val loss 4.729
# Ep 9 (Step 001210): Train loss 4.034, Val loss 4.726
# Ep 9 (Step 001215): Train loss 4.235, Val loss 4.713
# Ep 9 (Step 001220): Train loss 3.922, Val loss 4.724
# Ep 9 (Step 001225): Train loss 4.199, Val loss 4.720
# Ep 9 (Step 001230): Train loss 4.177, Val loss 4.700
# Ep 9 (Step 001235): Train loss 3.844, Val loss 4.706
# Ep 9 (Step 001240): Train loss 4.015, Val loss 4.686
# Ep 9 (Step 001245): Train loss 3.897, Val loss 4.703
# Ep 9 (Step 001250): Train loss 3.878, Val loss 4.737
# Ep 9 (Step 001255): Train loss 4.100, Val loss 4.735
# Ep 9 (Step 001260): Train loss 3.986, Val loss 4.721
# Ep 9 (Step 001265): Train loss 3.992, Val loss 4.713
# Ep 9 (Step 001270): Train loss 4.080, Val loss 4.699
# Ep 9 (Step 001275): Train loss 3.560, Val loss 4.692
# Ep 9 (Step 001280): Train loss 3.839, Val loss 4.685
# Ep 9 (Step 001285): Train loss 3.836, Val loss 4.706
# Ep 9 (Step 001290): Train loss 3.816, Val loss 4.683
# Ep 9 (Step 001295): Train loss 3.638, Val loss 4.677
# Ep 9 (Step 001300): Train loss 3.951, Val loss 4.690
# Ep 9 (Step 001305): Train loss 3.873, Val loss 4.702
# Ep 9 (Step 001310): Train loss 3.874, Val loss 4.708
# Ep 9 (Step 001315): Train loss 3.720, Val loss 4.686
# Ep 9 (Step 001320): Train loss 3.779, Val loss 4.680
# Ep 9 (Step 001325): Train loss 3.789, Val loss 4.715
# Ep 9 (Step 001330): Train loss 3.774, Val loss 4.713
# Ep 9 (Step 001335): Train loss 3.747, Val loss 4.698
# Ep 9 (Step 001340): Train loss 3.919, Val loss 4.736
# Every effort moves you.  LADY: I will not, sir, sir, sir, sir, sir, sir, sir, I'll not, sir, sir, sir, sir, sir, sir.  : LADY
# Ep 10 (Step 001345): Train loss 3.792, Val loss 4.689
# Ep 10 (Step 001350): Train loss 3.717, Val loss 4.683
# Ep 10 (Step 001355): Train loss 3.654, Val loss 4.695
# Ep 10 (Step 001360): Train loss 3.810, Val loss 4.678
# Ep 10 (Step 001365): Train loss 3.899, Val loss 4.679
# Ep 10 (Step 001370): Train loss 3.906, Val loss 4.670
# Ep 10 (Step 001375): Train loss 3.800, Val loss 4.644
# Ep 10 (Step 001380): Train loss 3.862, Val loss 4.658
# Ep 10 (Step 001385): Train loss 3.806, Val loss 4.683
# Ep 10 (Step 001390): Train loss 3.911, Val loss 4.677
# Ep 10 (Step 001395): Train loss 3.546, Val loss 4.681
# Ep 10 (Step 001400): Train loss 3.449, Val loss 4.652
# Ep 10 (Step 001405): Train loss 3.881, Val loss 4.692
# Ep 10 (Step 001410): Train loss 3.778, Val loss 4.663
# Ep 10 (Step 001415): Train loss 3.680, Val loss 4.686
# Ep 10 (Step 001420): Train loss 4.172, Val loss 4.673
# Ep 10 (Step 001425): Train loss 3.747, Val loss 4.677
# Ep 10 (Step 001430): Train loss 3.743, Val loss 4.659
# Ep 10 (Step 001435): Train loss 3.590, Val loss 4.645
# Ep 10 (Step 001440): Train loss 3.771, Val loss 4.638
# Ep 10 (Step 001445): Train loss 3.572, Val loss 4.662
# Ep 10 (Step 001450): Train loss 3.925, Val loss 4.638
# Ep 10 (Step 001455): Train loss 3.821, Val loss 4.676
# Ep 10 (Step 001460): Train loss 3.924, Val loss 4.692
# Ep 10 (Step 001465): Train loss 3.871, Val loss 4.666
# Ep 10 (Step 001470): Train loss 3.897, Val loss 4.703
# Ep 10 (Step 001475): Train loss 3.864, Val loss 4.679
# Ep 10 (Step 001480): Train loss 3.728, Val loss 4.667
# Ep 10 (Step 001485): Train loss 3.318, Val loss 4.645
# Every effort moves you, And I have you to your grace.  KING RICHARD III: I will not, I will not, I will not.  KING RICHARD III: I will not, I will not, I will
# 출력 텍스트:
#  Every effort moves you.
#
# CLARENCE:
# I am not, I'll tell
